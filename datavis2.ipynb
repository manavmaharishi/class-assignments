# %%
import pandas as pd

df = pd.read_csv("AWCustomers.csv")



selected_df = df[[
    "YearlyIncome", "Education", "Occupation", "Gender",
    "MaritalStatus", "HomeOwnerFlag", "NumberCarsOwned",
    "NumberChildrenAtHome", "TotalChildren"
   ]]
print(selected_df.head())
# Out:
#    YearlyIncome        Education      Occupation Gender MaritalStatus  \
# 0         81916        Bachelors        Clerical      M             M
# 1         81076  Partial College        Clerical      M             M
# 2         86387        Bachelors        Clerical      F             S
# 3         61481  Partial College  Skilled Manual      M             M
# 4         51804  Partial College  Skilled Manual      M             S
#
#    HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren
# 0              1                3                     0              1
# 1              1                2                     1              2
# 2              0                3                     0              0
# 3              1                2                     1              2
# 4              1                1                     0              0

# %%
data_types = {
    "Nominal": [
        "Occupation", 
        "Gender", 
        "MaritalStatus", 
        "HomeOwnerFlag", 
        "BikeBuyer"
    ],
    "Ordinal": [
        "Education", 
        "CommuteDistance"
    ],
    "Ratio (Continuous)": [
        "YearlyIncome", 
        "Age"
    ],
    "Ratio (Discrete)": [
        "NumberCarsOwned", 
        "NumberChildrenAtHome", 
        "TotalChildren"
    ]
}
print(data_types)
# Out:
# {'Nominal': ['Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag', 'BikeBuyer'], 'Ordinal': ['Education', 'CommuteDistance'], 'Ratio (Continuous)': ['YearlyIncome', 'Age'], 'Ratio (Discrete)': ['NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren']}
